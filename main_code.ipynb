# %%
import numpy as np
import pandas as pd

# %%
books=pd.read_csv('books.csv')
ratings=pd.read_csv('ratings.csv')
users=pd.read_csv('users.csv')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_15700\3107546550.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv('books.csv')

# %%
books.head()
# Out:
#          ISBN  ...                                        Image-URL-L
# 0  0195153448  ...  http://images.amazon.com/images/P/0195153448.0...
# 1  0002005018  ...  http://images.amazon.com/images/P/0002005018.0...
# 2  0060973129  ...  http://images.amazon.com/images/P/0060973129.0...
# 3  0374157065  ...  http://images.amazon.com/images/P/0374157065.0...
# 4  0393045218  ...  http://images.amazon.com/images/P/0393045218.0...
#
# [5 rows x 8 columns]

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
books.shape, ratings.shape, users.shape
# Out:
# ((271360, 8), (1149780, 3), (278858, 3))

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# np.int64(0)

# %%
ratings.duplicated().sum()
# Out:
# np.int64(0)

# %%
users.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# EDA

# %%
#books has missing values in 3 columns: 'image_url-l', 'book_author', and 'publisher'.
#ratings has no missing values.
#users has no missing values.
books['Book-Author'].fillna('Unknown', inplace=True)
books['Publisher'].fillna('Unknown', inplace=True)
books['Image-URL-L'].fillna('https://example.com/default_image.jpg', inplace=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_15700\3517170153.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   books['Book-Author'].fillna('Unknown', inplace=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_15700\3517170153.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# dtype: int64

# %%
#visualization
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.countplot(data=books, x='Book-Author', order=books['Book-Author'].value_counts().index[:10])
plt.xticks(rotation=45)
plt.title('Top 10 Authors in the Dataset')
plt.show()
plt.figure(figsize=(10, 6))
sns.countplot(data=books, x='Publisher', order=books['Publisher'].value_counts().index[:10])
plt.xticks(rotation=45)
plt.title('Top 10 Publishers in the Dataset')
plt.show()
plt.figure(figsize=(10, 6))
sns.countplot(data=ratings, x='Book-Rating', order=ratings['Book-Rating'].value_counts().index)
plt.title('Distribution of Book Ratings')
plt.show()  
plt.figure(figsize=(10, 6))
sns.countplot(data=users, x='Location', order=users['Location'].value_counts    ().index[:10])
plt.xticks(rotation=45)
plt.title('Top 10 Locations of Users')
plt.show()

# %% [markdown]
# Popularity Based Recommender System

# %%
#Top 50 books by average rating
ratings_with_name=ratings.merge(books, on='ISBN')

# %%
ratings_with_name
# Out:
#          User-ID  ...                                        Image-URL-L
# 0         276725  ...  http://images.amazon.com/images/P/034545104X.0...
# 1         276726  ...  http://images.amazon.com/images/P/0155061224.0...
# 2         276727  ...  http://images.amazon.com/images/P/0446520802.0...
# 3         276729  ...  http://images.amazon.com/images/P/052165615X.0...
# 4         276729  ...  http://images.amazon.com/images/P/0521795028.0...
# ...          ...  ...                                                ...
# 1031131   276704  ...  http://images.amazon.com/images/P/0876044011.0...
# 1031132   276704  ...  http://images.amazon.com/images/P/1563526298.0...
# 1031133   276706  ...  http://images.amazon.com/images/P/0679447156.0...
# 1031134   276709  ...  http://images.amazon.com/images/P/0515107662.0...
# 1031135   276721  ...  http://images.amazon.com/images/P/0590442449.0...
#
# [1031136 rows x 10 columns]

# %%
num_rating_df=ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating': 'num_rating'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_rating
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
# [241071 rows x 2 columns]

# %%
# Make sure Book-Rating is numeric
ratings_with_name['Book-Rating'] = pd.to_numeric(ratings_with_name['Book-Rating'], errors='coerce')
# Now group and calculate the mean
avg_rating_df = (
    ratings_with_name
    .groupby('Book-Title', as_index=False)['Book-Rating']
    .mean()
    .rename(columns={'Book-Rating': 'avg_rating'})
)
avg_rating_df.head()
# Out:
#                                           Book-Title  avg_rating
# 0   A Light in the Storm: The Civil War Diary of ...        2.25
# 1                              Always Have Popsicles        0.00
# 2               Apple Magic (The Collector's series)        0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...        8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...        0.00

# %%
popular_df = num_rating_df.merge(avg_rating_df, on='Book-Title')
popular_df
# Out:
#                                                Book-Title  ...  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...  ...    2.250000
# 1                                   Always Have Popsicles  ...    0.000000
# 2                    Apple Magic (The Collector's series)  ...    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...  ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...  ...    0.000000
# ...                                                   ...  ...         ...
# 241066                                      Ã?Â?lpiraten.  ...    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.  ...    5.250000
# 241068                                Ã?Â?sterlich leben.  ...    7.000000
# 241069                              Ã?Â?stlich der Berge.  ...    2.666667
# 241070                                  Ã?Â?thique en toc  ...    4.000000
#
# [241071 rows x 3 columns]

# %%
popular_df=popular_df[popular_df['num_rating'] >= 250].sort_values('avg_rating', ascending=False).head(50)

# %%
popular_df=popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title', 'Book-Author', 'avg_rating', 'num_rating', 'Image-URL-L']].reset_index(drop=True)

# %%
popular_df
# Out:
#                                            Book-Title  ...                                        Image-URL-L
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)  ...  http://images.amazon.com/images/P/0439136350.0...
# 1        Harry Potter and the Goblet of Fire (Book 4)  ...  http://images.amazon.com/images/P/0439139597.0...
# 2      Harry Potter and the Sorcerer's Stone (Book 1)  ...  http://images.amazon.com/images/P/0590353403.0...
# 3   Harry Potter and the Order of the Phoenix (Boo...  ...  http://images.amazon.com/images/P/043935806X.0...
# 4    Harry Potter and the Chamber of Secrets (Book 2)  ...  http://images.amazon.com/images/P/0439064872.0...
# 5   The Hobbit : The Enchanting Prelude to The Lor...  ...  http://images.amazon.com/images/P/0345339681.0...
# 6   The Fellowship of the Ring (The Lord of the Ri...  ...  http://images.amazon.com/images/P/0345339703.0...
# ...

# %% [markdown]
# Collabrative Filtering Based Recommender System

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
padhe_likhe_users = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(padhe_likhe_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     ...  278418
# Book-Title                                                  ...
# 1984                                                   9.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# [706 rows x 810 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg']]

# %%
pt.index[545]
# Out:
# "The Handmaid's Tale"

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
books.drop_duplicates('Book-Title')
# Out:
#               ISBN  ...                                        Image-URL-L
# 0       0195153448  ...  http://images.amazon.com/images/P/0195153448.0...
# 1       0002005018  ...  http://images.amazon.com/images/P/0002005018.0...
# 2       0060973129  ...  http://images.amazon.com/images/P/0060973129.0...
# 3       0374157065  ...  http://images.amazon.com/images/P/0374157065.0...
# 4       0393045218  ...  http://images.amazon.com/images/P/0393045218.0...
# ...            ...  ...                                                ...
# 271354  0449906736  ...  http://images.amazon.com/images/P/0449906736.0...
# 271356  0525447644  ...  http://images.amazon.com/images/P/0525447644.0...
# 271357  006008667X  ...  http://images.amazon.com/images/P/006008667X.0...
# 271358  0192126040  ...  http://images.amazon.com/images/P/0192126040.0...
# 271359  0767409752  ...  http://images.amazon.com/images/P/0767409752.0...
#
# [242135 rows x 8 columns]

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity_scores = cosine_similarity(pt)
print(similarity_scores)
# Out:
# [[1.         0.10255025 0.01220856 ... 0.12110367 0.07347567 0.04316046]
#  [0.10255025 1.         0.2364573  ... 0.07446129 0.16773875 0.14263397]
#  [0.01220856 0.2364573  1.         ... 0.04558758 0.04938579 0.10796119]
#  ...
#  [0.12110367 0.07446129 0.04558758 ... 1.         0.07085128 0.0196177 ]
#  [0.07347567 0.16773875 0.04938579 ... 0.07085128 1.         0.10602962]
#  [0.04316046 0.14263397 0.10796119 ... 0.0196177  0.10602962 1.        ]]

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    #index fetch
    index = np.where(pt.index==book_name)[0][0]
    distances = similarity_scores[index]
    similar_items = sorted(list(enumerate(distances)),key=lambda x:x[1],reverse=True)[1:6]
    for i in similar_items:
        print(pt.index[i[0]])

# %%
recommend('1984')
# Out:
# Animal Farm
# The Handmaid's Tale
# Brave New World
# The Vampire Lestat (Vampire Chronicles, Book II)
# The Hours : A Novel

# %%
recommend('Message in a Bottle')
# Out:
# Nights in Rodanthe
# The Mulberry Tree
# A Walk to Remember
# River's End
# Nightmares &amp; Dreamscapes
